# %%
name = 'sanjai'
age = 22
profession = 'engg'

# %%
print(name,'is',age,'years old and he is an',profession)
# Out:
# sanjai is 22 years old and he is an engg

# %%
f'{name} is {age} years old and he is an {profession}'
# Out:
# 'sanjai is 22 years old and he is an engg'

# %%
print(f'{name} is {age} years old and he is an {profession}')
# Out:
# sanjai is 22 years old and he is an engg

# %% [markdown]
# # data structures
#
# ## list

# %%
list1 = [2,4,5,10,4,6,12,10,20,100,2]

# %%
len(list1)
# Out:
# 11

# %%
max(list1)
# Out:
# 100

# %%
min(list1)
# Out:
# 2

# %%
sum(list1)
# Out:
# 175

# %%
type(list1)
# Out:
# list

# %%
list1
# Out:
# [2, 4, 5, 10, 4, 6, 12, 10, 20, 100, 2]

# %%
list1[6]
# Out:
# 12

# %%
list1[:4]
# Out:
# [2, 4, 5, 10]

# %%
list1[-3:]
# Out:
# [20, 100, 2]

# %%
list1[6] = 200

# %%
list1
# Out:
# [2, 4, 5, 10, 4, 6, 200, 10, 20, 100, 2]

# %%
list1.append(100)

# %%
list1
# Out:
# [2, 4, 5, 10, 4, 6, 200, 10, 20, 100, 2, 100]

# %%
list1.insert(4,1000)

# %%
list1
# Out:
# [2, 4, 5, 10, 1000, 4, 6, 200, 10, 20, 100, 2, 100]

# %%
list1.remove(200)

# %%
list1
# Out:
# [2, 4, 5, 10, 1000, 4, 6, 10, 20, 100, 2, 100]

# %%
list1.index(10)
# Out:
# 3

# %%
## if you want the second 10 in the list

# %%
list1.index(10,4)
# Out:
# 7

# %%
list1.pop(7) # user to delete where we want
# Out:
# 10

# %%
list1
# Out:
# [2, 4, 5, 10, 1000, 4, 6, 20, 100, 2, 100]

# %%
list1.remove(10) removes the first comming value u gave

# %%
list1
# Out:
# [2, 4, 5, 1000, 4, 6, 20, 100, 2, 100]

# %%
list1.sort()

# %%
list1
# Out:
# [2, 2, 4, 4, 5, 6, 20, 100, 100, 1000]

# %%
list1.sort(reverse = True)

# %%
list1
# Out:
# [1000, 100, 100, 20, 6, 5, 4, 4, 2, 2]

# %% [markdown]
# ## tuple

# %%
tuple1 = (2,6,8,10,12,18,20,10)

# %%
type(tuple1)
# Out:
# tuple

# %%
tuple1.count(10) # counts how many times it appears
# Out:
# 2

# %%
tuple1.index(8) # index value of the particular value u need
# Out:
# 2

# %% [markdown]
# ## set

# %%
set1={2,4,5,10,10,15,8,7.22,50,22,20}

type(set1)
# Out:
# set

# %%
set1
# Out:
# {2, 4, 5, 7.22, 8, 10, 15, 20, 22, 50}

# %%
# its will take only unique values and it sort in asce order

# %%
set1.add(12) #it will not add at the last

# %%
set1
# Out:
# {2, 4, 5, 7.22, 8, 10, 12, 15, 20, 22, 50}

# %%
set1.remove(7.22)

# %%
set1
# Out:
# {2, 4, 5, 8, 10, 12, 15, 20, 22, 50}

# %%
set2 = set1.copy()

# %%
set2
# Out:
# {2, 4, 5, 8, 10, 12, 15, 20, 22, 50}

# %%
set2.add(100)

# %%
set2.add(200)

# %%
set2
# Out:
# {2, 4, 5, 8, 10, 12, 15, 20, 22, 50, 100, 200}

# %%
set1.union(set2)
# Out:
# {2, 4, 5, 8, 10, 12, 15, 20, 22, 50, 100, 200}

# %%
set1 | set2 # we can use union function or pipe symbol
# Out:
# {2, 4, 5, 8, 10, 12, 15, 20, 22, 50, 100, 200}

# %%
set1.intersection(set2)
# Out:
# {2, 4, 5, 8, 10, 12, 15, 20, 22, 50}

# %%
set1&set2 # we can use intersection function or abresent symbol
# Out:
# {2, 4, 5, 8, 10, 12, 15, 20, 22, 50}

# %%
set1.difference(set2)
# Out:
# set()

# %%
set1 - set2 # we can use difference function or minus symbol
# Out:
# set()

# %%
set2 - set1
# Out:
# {100, 200}

# %%
a = {2,4,6,8}
b = {8,10}

# %%
b.update(a)

# %%
b
# Out:
# {2, 4, 6, 8, 10}

# %% [markdown]
# ## dictionaries

# %%
dic = {'name' :['sanjai','krish','dhaya','priya'],
       'age':[22,33,23,32],'gender':['male','male','male','female']}

# %%
type(dic)
# Out:
# dict

# %%
dic.keys()
# Out:
# dict_keys(['name', 'age', 'gender'])

# %%
dic.values()
# Out:
# dict_values([['sanjai', 'krish', 'dhaya', 'priya'], [22, 33, 23, 32], ['male', 'male', 'male', 'female']])

# %%
dic.items() # shows both keys and values
# Out:
# dict_items([('name', ['sanjai', 'krish', 'dhaya', 'priya']), ('age', [22, 33, 23, 32]), ('gender', ['male', 'male', 'male', 'female'])])

# %%
dic.get('name')
# Out:
# ['sanjai', 'krish', 'dhaya', 'priya']

# %%
dic.setdefault('loction',['pune','mumbai','chennai','blr'])
# Out:
# ['pune', 'mumbai', 'chennai', 'blr']

# %%
dic
# Out:
# {'name': ['sanjai', 'krish', 'dhaya', 'priya'],
#  'age': [22, 33, 23, 32],
#  'gender': ['male', 'male', 'male', 'female'],
#  'loction': ['pune', 'mumbai', 'chennai', 'blr']}

# %%
dic.items()
# Out:
# dict_items([('name', ['sanjai', 'krish', 'dhaya', 'priya']), ('age', [22, 33, 23, 32]), ('gender', ['male', 'male', 'male', 'female']), ('loction', ['pune', 'mumbai', 'chennai', 'blr'])])

# %%
dic1 = dic.copy()

# %%
dic1
# Out:
# {'name': ['sanjai', 'krish', 'dhaya', 'priya'],
#  'age': [22, 33, 23, 32],
#  'gender': ['male', 'male', 'male', 'female'],
#  'loction': ['pune', 'mumbai', 'chennai', 'blr']}

# %%
dic1.pop('gender')
# Out:
# ['male', 'male', 'male', 'female']

# %%
dic1
# Out:
# {'name': ['sanjai', 'krish', 'dhaya', 'priya'],
#  'age': [22, 33, 23, 32],
#  'loction': ['pune', 'mumbai', 'chennai', 'blr']}

# %%
dic1.popitem() # remove last key and value -- default
# Out:
# ('age', [22, 33, 23, 32])

# %%
dict1={'Name':['a','b','c'],'Age':[22,23,24]}

dict2= {'Name':['a','b','e'],'Gender':['m','m','f']}

# %%
dict2.update(dict1)

# %%
dict2
# Out:
# {'Name': ['a', 'b', 'c'], 'Gender': ['m', 'm', 'f'], 'Age': [22, 23, 24]}

# %%
for i in list1: # for loop
    print(i)
# Out:
# 1000
# 100
# 100
# 20
# 6
# 5
# 4
# 4
# 2
# 2

# %%
for i in enumerate(list1): # give the index value,data
    print(i)
# Out:
# (0, 1000)
# (1, 100)
# (2, 100)
# (3, 20)
# (4, 6)
# (5, 5)
# (6, 4)
# (7, 4)
# (8, 2)
# (9, 2)

# %%
range(1,6)
# Out:
# range(1, 6)

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## list comprehenison

# %%
[i for i in list1] # get output in list form
# Out:
# [1000, 100, 100, 20, 6, 5, 4, 4, 2, 2]

# %%
[i+5 for i in list1]
# Out:
# [1005, 105, 105, 25, 11, 10, 9, 9, 7, 7]

# %%
[i+i for i in list1]
# Out:
# [2000, 200, 200, 40, 12, 10, 8, 8, 4, 4]
