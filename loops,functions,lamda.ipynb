# %%
dic = {'name' :['sanjai','krish','dhaya','priya'],
       'age':[22,33,23,32],'gender':['male','male','male','female']}

# %%
for i,j in dic.items():
    print(i,j)
# Out:
# name ['sanjai', 'krish', 'dhaya', 'priya']
# age [22, 33, 23, 32]
# gender ['male', 'male', 'male', 'female']

# %% [markdown]
# ## while loop

# %%
i = 1
n = 5
sum1 = 0
while(i<n):
    sum1+=i
    print(sum1)
    i+=1
# Out:
# 1
# 3
# 6
# 10

# %%
counter = 1
while(counter < 10):
    print('counter')
    counter+=1
else:
    print('end')
# Out:
# counter
# counter
# counter
# counter
# counter
# counter
# counter
# counter
# counter
# end

# %%
n = int(input('enter a number'))
if n >10:
    x = n+1
    print(x)
elif n < 10:
    x = n-1
    print(x)
else:
    print(n)
# Out:
# enter a number 10
# 10

# %%
##find th enumber is even or odd
n = int(input('enter a number'))
if n%2 == 0:
    print(n,'even')
else:
    print(n,'odd')
# Out:
# enter a number 3
# 3 odd

# %%
n = int(input('enter a number'))
if n>0:
    print(n,'is positive')
elif n<0:
    print(n,'is negative')
else:
    print(n,'is zero')
# Out:
# enter a number -12
# -12 is negative

# %%
list1 = [1,2,3,4,5]
odd=[]
even=[]
for i in list1:
    if i%2 == 0:
        even.append(i)
        
    else:
        odd.append(i)
print(odd)
print(even)
# Out:
# [1, 3, 5]
# [2, 4]

# %% [markdown]
# ## functions

# %%
def add(x,y,z):
    return x+y+z

# %%
add(1,2,3)
# Out:
# 6

# %%
def mul(x,y):
    return x*y

# %%
mul(2,2)
# Out:
# 4

# %%
def even_odd(x):
    if x%2==0:
        return 'even'
    else:
        return 'odd'

# %%
even_odd(3)
# Out:
# 'odd'

# %%
def even_odd(a):
    even=[]
    odd=[]
    for i in a:
        if i%2==0:
            even.append(i) 
        else:
            odd.append(i)
    return even,odd

# %%
even_odd([1,2,3,4,5,6])
# Out:
# ([2, 4, 6], [1, 3, 5])

# %% [markdown]
# 1. Take a string and write a python code to find  the vowels in the string.
#
# 2. Create a list through loop.
#
# 3. Use function to find a prime number.
#
# 4. write a python code to find the area of a circle.

# %%
# !git add .

# %%
# !git commit -m 'day 3 added'
# Out:
# [main 21ee256] day 3 added
#  2 files changed, 415 insertions(+), 40 deletions(-)
#  create mode 100644 loops,functions,lamda.ipynb

# %%
# !git push origin main
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 2.18 KiB | 2.18 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/sanjai570/data-science.git
#    6a9f891..21ee256  main -> main
