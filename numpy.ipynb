# %%
import numpy as np

# %%
## one dimensional array
arr_1 = np.array([2,19,2,15,100,50,6,79,88])
arr_1
# Out:
# array([  2,  19,   2,  15, 100,  50,   6,  79,  88])

# %%
type(arr_1)
# Out:
# numpy.ndarray

# %%
arr_1.ndim
# Out:
# 1

# %%
arr_1.size
# Out:
# 9

# %%
arr_1[4]
# Out:
# np.int64(100)

# %%
arr_1[:4]
# Out:
# array([ 2, 19,  2, 15])

# %%
## mutabile
arr_1[4] = 200

# %%
## insert cannot change the data permenantly 
np.insert(arr_1,4,100)
# Out:
# array([  2,  19,   2,  15, 100, 200,  50,   6,  79,  88])

# %%
arr_1
# Out:
# array([  2,  19,   2,  15, 200,  50,   6,  79,  88])

# %%
## but by putting that into a new variable we can create a new array using that
arr_1_dummy = np.insert(arr_1,4,100)

# %%
arr_1_dummy
# Out:
# array([  2,  19,   2,  15, 100, 200,  50,   6,  79,  88])

# %%
##same for delete also
np.delete(arr_1,4)
# Out:
# array([ 2, 19,  2, 15, 50,  6, 79, 88])

# %%
arr_1
# Out:
# array([  2,  19,   2,  15, 200,  50,   6,  79,  88])

# %%
arr_1_delete_dummy = np.delete(arr_1,4)

# %%
arr_1_delete_dummy
# Out:
# array([ 2, 19,  2, 15, 50,  6, 79, 88])
