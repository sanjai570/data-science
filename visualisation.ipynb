# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
Exp=[1,2,4,6,10,15]
Sal=[1000,2500,3000,5000,10000,15000]

# %%
## scatter plot
plt.scatter(Exp,Sal)

# %%
plt.scatter(Exp,Sal,marker = '*')

# %%
plt.figure(figsize = (5,5))
plt.title('exp X sal' , color = 'green' , size = 14)
plt.scatter(Exp,Sal,color = 'red')
plt.xlabel('experince',color = 'green',size = 12)
plt.ylabel('salary',color = 'green',size = 12)
plt.grid()

# %%
plt.figure(figsize = (5,5))
plt.title('exp X sal' , color = 'green' , size = 14)
plt.plot(Exp,Sal,color = 'red',marker = 'o',linestyle='--',markerfacecolor='green',lw = 2)
plt.xlabel('experince',color = 'green',size = 12)
plt.ylabel('salary',color = 'green',size = 12)
plt.grid()

# %%
# !git add .

# %%
# !git push
# Out:
# Everything up-to-date

# %%
# !git commit -m 'visualisation added'
# Out:
# [main ffb89f4] visualisation added
#  3 files changed, 1698 insertions(+), 1 deletion(-)
#  create mode 100644 Housing_data.csv
#  create mode 100644 practice.ipynb

# %%
plt.bar(Exp,Sal,color = 'red',width = 0.9)
plt.title('exp X sal' , color = 'green' , size = 14)
plt.plot(Exp,Sal,color = 'red',marker = 'o',linestyle='--',markerfacecolor='green',lw = 2)
plt.xlabel('experince',color = 'green',size = 12)
plt.ylabel('salary',color = 'green',size = 12)
plt.grid()

# %%
#### Pie chart
Marks= [100,90,88,75,60,79]
Names=['Ajay','Ramesh','John','Tom','Ramya','Sanjay']
colors=['red','purple','green','brown','blue','orange']

# %%
plt.pie(Marks,labels = Names,colors = colors,radius = 1,autopct = '%.2f%%',textprops = 
       
       {'color':'black','size':10},wedgeprops = {'linewidth':5,'edgecolor':'black'},shadow = True,explode=[0.1,0,0,0,0.1,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x177d8f620>,
# ...
#  [Text(0.9635636868932347, 0.7152237561076369, 'Ajay'),
#   Text(-0.30500104210812384, 1.0568700792022445, 'Ramesh'),
#   Text(-1.0871084596166836, 0.16791425499296295, 'John'),
#   Text(-0.6944337944774682, -0.8530895059064, 'Tom'),
#   Text(0.21340691342223567, -1.1808714956774908, 'Ramya'),
#   Text(0.9629884581454664, -0.5316514172638096, 'Sanjay')],
#  [Text(0.5620788173543868, 0.41721385772945485, '20.33%'),
#   Text(-0.16636420478624933, 0.5764745886557696, '18.29%'),
#   Text(-0.5929682507000091, 0.09158959363252524, '17.89%'),
#   Text(-0.3787820697149826, -0.4653215486762181, '15.24%'),
#   Text(0.1244873661629708, -0.6888417058118697, '12.20%'),
#   Text(0.5252664317157089, -0.2899916821438961, '16.06%')])

# %%
## subplots 
plt.subplots(2,2,figsize = (7,5))
# Out:
# (<Figure size 700x500 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
fig,axis = plt.subplots(2,2,figsize = (10,8))
plt.suptitle('performance measure',color ='green',size = 14)
axis[0,0].scatter(Exp,Sal,color = 'red')
axis[0,0].set_title('exp X sal' , color = 'green' , size = 12)
axis[0,0].set_xlabel('experince',color = 'green',size = 10)
axis[0,0].set_ylabel('salary',color = 'green',size = 10)

axis[0,1].set_title('exp X sal' , color = 'green' , size = 12)
axis[0,1].plot(Exp,Sal,color = 'red',marker = 'o',linestyle='--',markerfacecolor='green',lw = 2)
axis[0,1].set_xlabel('experince',color = 'green',size = 10)
axis[0,1].set_ylabel('salary',color = 'green',size = 10)

axis[1,0].bar(Exp,Sal,color = 'red',width = 0.9)
axis[1,0].set_title('exp X sal' , color = 'green' , size = 12)
axis[1,0].plot(Exp,Sal,color = 'red',marker = 'o',linestyle='--',markerfacecolor='green',lw = 2)
axis[1,0].set_xlabel('experince',color = 'green',size = 10)
axis[1,0].set_ylabel('salary',color = 'green',size = 10)

axis[1,1].pie(Marks,labels = Names,colors = colors,radius = 1,autopct = '%.2f%%',textprops = {'color':'black','size':10},wedgeprops = {'linewidth':5,'edgecolor':'black'},shadow = True,explode=[0.1,0,0,0,0.1,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x172b7ac10>,
# ...
#  [Text(0.9635636868932347, 0.7152237561076369, 'Ajay'),
#   Text(-0.30500104210812384, 1.0568700792022445, 'Ramesh'),
#   Text(-1.0871084596166836, 0.16791425499296295, 'John'),
#   Text(-0.6944337944774682, -0.8530895059064, 'Tom'),
#   Text(0.21340691342223567, -1.1808714956774908, 'Ramya'),
#   Text(0.9629884581454664, -0.5316514172638096, 'Sanjay')],
#  [Text(0.5620788173543868, 0.41721385772945485, '20.33%'),
#   Text(-0.16636420478624933, 0.5764745886557696, '18.29%'),
#   Text(-0.5929682507000091, 0.09158959363252524, '17.89%'),
#   Text(-0.3787820697149826, -0.4653215486762181, '15.24%'),
#   Text(0.1244873661629708, -0.6888417058118697, '12.20%'),
#   Text(0.5252664317157089, -0.2899916821438961, '16.06%')])

# %%
import pandas as pd
df = pd.read_csv('diamonds.csv')

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
#scatter plot

sns.scatterplot(data = df,x = 'carat' , y = 'price' ,color = 'red')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
df.cut.values
# Out:
# array(['Ideal', 'Premium', 'Good', ..., 'Very Good', 'Premium', 'Ideal'],
#       shape=(53940,), dtype=object)

# %%
df.cut.value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
cntplt =  sns.countplot(data = df, x = 'cut')
cntplt.bar_label(cntplt.containers[0])
# Out:
# [Text(0, 0, '21551'),
#  Text(0, 0, '13791'),
#  Text(0, 0, '4906'),
#  Text(0, 0, '12082'),
#  Text(0, 0, '1610')]

# %%
# histogram 
sns.histplot(data = df, x = 'carat' ,kde = True, color = 'red',bins = 100 ) #kde kernel distributed estimate
# Out:
# <Axes: xlabel='carat', ylabel='Count'>

# %%
## density plot
sns.kdeplot(data = df, x = 'carat')
# Out:
# <Axes: xlabel='carat', ylabel='Density'>

# %%
sns.kdeplot(data = df, x = 'carat',fill = True,color = 'grey',alpha = 0.4)
# Out:
# <Axes: xlabel='carat', ylabel='Density'>

# %%
# to seperate numerical and catogorical columns

num_col = df.select_dtypes(include = ['int','float']).columns
print(num_col)

cat_col = df.select_dtypes(include = 'object').columns
print(cat_col)
# Out:
# Index(['carat', 'depth', 'table', 'price', 'x', 'y', 'z'], dtype='object')
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
## supplot -- histogram

for i in range(len(num_col)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
plt.figure(figsize = (15,15))
for i in range(len(num_col)):
    plt.subplot(4,2,i+1)
    sns.histplot(x = df[num_col[i]])
    plt.tight_layout()

# %%
plt.figure(figsize = (12,7))
for i in range(len(num_col)):
    plt.subplot(4,2,i+1)
    sns.kdeplot(x = df[num_col[i]])
    plt.tight_layout()

# %%
plt.figure(figsize = (12,7))
for i in range(len(num_col)):
    plt.subplot(4,2,i+1)
    sns.boxplot(x = df[num_col[i]])
    plt.tight_layout()

# %%
plt.figure(figsize = (12,7))
for i in range(len(cat_col)):
    plt.subplot(4,2,i+1)
    sns.countplot(x = df[cat_col[i]])
    plt.tight_layout()

# %%
len(cat_col)
# Out:
# 3

# %%
# box plot
sns.boxplot(data = df, x = 'carat')
# Out:
# <Axes: xlabel='carat'>

# %%
for col in num_col:
    sns.boxplot(data = df , y = col)
    plt.show()

# %%
for col in num_col:
    sns.boxplot(data = df , x = col)
    plt.show()

# %%
# violin plot
sns.violinplot(data = df , y = 'carat')
# Out:
# <Axes: ylabel='carat'>

# %%
sns.catplot(data = df , x = 'cut' , y = 'carat' ,kind = 'violin')

# %%
# !git add .

# %%
# !git commit -m 'seaborn added'
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 93.06 KiB | 15.51 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/sanjai570/data-science.git
#    1f62394..ffb89f4  main -> main

# %%
## jointplot
sns.jointplot(data = df , x = 'carat' , y = 'price')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
## pairplot
sns.pairplot(data = df)

# %%
sns.pairplot(data = df[['carat','price','depth','table']] )

# %%
## coveriance - only for numerical columns
df[num_col].cov()
# Out:
#              carat      depth        table         price            x  \
# carat     0.224687   0.019167     0.192365  1.742765e+03     0.518484
# depth     0.019167   2.052404    -0.946840 -6.085371e+01    -0.040641
# table     0.192365  -0.946840     4.992948  1.133318e+03     0.489643
# price  1742.765364 -60.853712  1133.318064  1.591563e+07  3958.021491
# x         0.518484  -0.040641     0.489643  3.958021e+03     1.258347
# y         0.515248  -0.048009     0.468972  3.943271e+03     1.248789
# z         0.318917   0.095968     0.237996  2.424713e+03     0.768487
#
#                  y            z
# carat     0.515248     0.318917
# depth    -0.048009     0.095968
# table     0.468972     0.237996
# price  3943.270810  2424.712613
# x         1.248789     0.768487
# y         1.304472     0.767320
# z         0.767320     0.498011

# %%
## correlation 
corr=df[num_col].corr()
corr
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
## heatmap
sns.heatmap(corr,annot = True)
# Out:
# <Axes: >

# %%
sns.heatmap(corr,annot = True,cmap = plt.cm.Accent)
# Out:
# <Axes: >
