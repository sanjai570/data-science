# %%
import pandas as pd

# %%
## series
ser1 = pd.Series(data=[90,88,77,66,55,44],index=['ajay','sanjai','ramesh','suman','john','tom'])

# %%
ser1
# Out:
# ajay      90
# sanjai    88
# ramesh    77
# suman     66
# john      55
# tom       44
# dtype: int64

# %%
dict1= {'Name':['Ramesh','Sanjay','Ramya','Suman','John'],'Age':[22,25,30,28,32],

        'Gender':['Male','Male','Female','Female','Male'],

        'Location':['Bengaluru','Chennai','Pune','Bengaluru','Calcutta']}

# %%
df = pd.DataFrame(dict1,index = range(1,6))
df
# Out:
#      Name  Age  Gender   Location
# 1  Ramesh   22    Male  Bengaluru
# 2  Sanjay   25    Male    Chennai
# 3   Ramya   30  Female       Pune
# 4   Suman   28  Female  Bengaluru
# 5    John   32    Male   Calcutta

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 1 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5 non-null      object
#  1   Age       5 non-null      int64
#  2   Gender    5 non-null      object
#  3   Location  5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 292.0+ bytes

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Location'], dtype='object')

# %%
df.Gender
# Out:
# 1      Male
# 2      Male
# 3    Female
# 4    Female
# 5      Male
# Name: Gender, dtype: object

# %%
df
# Out:
#      Name  Age  Gender   Location
# 1  Ramesh   22    Male  Bengaluru
# 2  Sanjay   25    Male    Chennai
# 3   Ramya   30  Female       Pune
# 4   Suman   28  Female  Bengaluru
# 5    John   32    Male   Calcutta

# %%
df.Age.sort_values()
# Out:
# 1    22
# 2    25
# 4    28
# 3    30
# 5    32
# Name: Age, dtype: int64

# %%
df['Age'].sort_values()
# Out:
# 1    22
# 2    25
# 4    28
# 3    30
# 5    32
# Name: Age, dtype: int64

# %%
df.sort_values(by='Age')
# Out:
#      Name  Age  Gender   Location
# 1  Ramesh   22    Male  Bengaluru
# 2  Sanjay   25    Male    Chennai
# 4   Suman   28  Female  Bengaluru
# 3   Ramya   30  Female       Pune
# 5    John   32    Male   Calcutta

# %%
df.sort_values(by='Age',ascending=False)
# Out:
#      Name  Age  Gender   Location
# 5    John   32    Male   Calcutta
# 3   Ramya   30  Female       Pune
# 4   Suman   28  Female  Bengaluru
# 2  Sanjay   25    Male    Chennai
# 1  Ramesh   22    Male  Bengaluru

# %%
df.drop(columns = ['Gender'])
# Out:
#      Name  Age   Location
# 1  Ramesh   22  Bengaluru
# 2  Sanjay   25    Chennai
# 3   Ramya   30       Pune
# 4   Suman   28  Bengaluru
# 5    John   32   Calcutta

# %%
df
# Out:
#      Name  Age  Gender   Location
# 1  Ramesh   22    Male  Bengaluru
# 2  Sanjay   25    Male    Chennai
# 3   Ramya   30  Female       Pune
# 4   Suman   28  Female  Bengaluru
# 5    John   32    Male   Calcutta

# %%
## if u want to delete a column permntely
df.drop(columns = ['Gender'],inplace = True)

# %%
df.rename(columns = {'Location':'place'})
# Out:
#      Name  Age  Gender      place
# 1  Ramesh   22    Male  Bengaluru
# 2  Sanjay   25    Male    Chennai
# 3   Ramya   30  Female       Pune
# 4   Suman   28  Female  Bengaluru
# 5    John   32    Male   Calcutta

# %%
df[(df.Gender == 'Male') & (df.Location == 'Chennai')]
# Out:
#      Name  Age Gender Location
# 2  Sanjay   25   Male  Chennai

# %%
df.Location.unique()
# Out:
# array(['Bengaluru', 'Chennai', 'Pune', 'Calcutta'], dtype=object)

# %%
df.Location.value_counts()
# Out:
# Location
# Bengaluru    2
# Chennai      1
# Pune         1
# Calcutta     1
# Name: count, dtype: int64

# %%
df.Age.min()
# Out:
# 22

# %%
df.Age.max()
# Out:
# 32

# %%
df.Age.mean()
# Out:
# np.float64(27.4)

# %%
df.Age.median()
# Out:
# 28.0

# %%
df.Age.mode()
# Out:
# 0    22
# 1    25
# 2    28
# 3    30
# 4    32
# Name: Age, dtype: int64

# %%
df.describe()
# Out:
#              Age
# count   5.000000
# mean   27.400000
# std     3.974921
# min    22.000000
# 25%    25.000000
# 50%    28.000000
# 75%    30.000000
# max    32.000000

# %%
df.Name.describe()
# Out:
# count          5
# unique         5
# top       Ramesh
# freq           1
# Name: Name, dtype: object

# %%
df.describe(include = 'all')
# Out:
#           Name        Age Gender   Location
# count        5   5.000000      5          5
# unique       5        NaN      2          4
# top     Ramesh        NaN   Male  Bengaluru
# freq         1        NaN      3          2
# mean       NaN  27.400000    NaN        NaN
# std        NaN   3.974921    NaN        NaN
# min        NaN  22.000000    NaN        NaN
# 25%        NaN  25.000000    NaN        NaN
# 50%        NaN  28.000000    NaN        NaN
# 75%        NaN  30.000000    NaN        NaN
# max        NaN  32.000000    NaN        NaN

# %%
df.iloc[1]
# Out:
# Name         Sanjay
# Age              25
# Gender         Male
# Location    Chennai
# Name: 2, dtype: object

# %%
df.iloc[:3]
# Out:
#      Name  Age  Gender   Location
# 1  Ramesh   22    Male  Bengaluru
# 2  Sanjay   25    Male    Chennai
# 3   Ramya   30  Female       Pune

# %%
df.iloc[[0,2,4],[0,2,3]]
# Out:
#      Name  Gender   Location
# 1  Ramesh    Male  Bengaluru
# 3   Ramya  Female       Pune
# 5    John    Male   Calcutta

# %%
## to find the column of a particular index
df.columns.get_loc('Gender')
# Out:
# 2

# %%
df.loc[3]
# Out:
# Name         Ramya
# Age             30
# Gender      Female
# Location      Pune
# Name: 3, dtype: object

# %%
df.loc[1:4]
# Out:
#      Name  Age  Gender   Location
# 1  Ramesh   22    Male  Bengaluru
# 2  Sanjay   25    Male    Chennai
# 3   Ramya   30  Female       Pune
# 4   Suman   28  Female  Bengaluru

# %%
df.loc[:,:'Gender']
# Out:
#      Name  Age  Gender
# 1  Ramesh   22    Male
# 2  Sanjay   25    Male
# 3   Ramya   30  Female
# 4   Suman   28  Female
# 5    John   32    Male

# %%
df.loc[[1,2,4],['Name','Gender','Location']]
# Out:
#      Name  Gender   Location
# 1  Ramesh    Male  Bengaluru
# 2  Sanjay    Male    Chennai
# 4   Suman  Female  Bengaluru

# %%
df = pd.read_csv('CARS_1.CSV')

# %%
df
# Out:
#     name_of_car                    Model                             Type  \
# 0         Acura   NSX coupe 2dr manual S                           Sports
# 1         Acura  3.5 RL w/Navigation 4dr                            Sedan
# 2         Acura               3.5 RL 4dr                            Sedan
# 3         Acura                      MDX                              NaN
# 4         Acura                   TL 4dr                              NaN
# ..          ...                      ...                              ...
# 438         NaN                      NaN                              NaN
# 439         NaN                      NaN                              NaN
# 440         NaN                group by                1) data will split
# 441         NaN                      NaN  2) apply the function mean(mpg)
# 442         NaN                      NaN                       3) combine
#
#     Origin DriveTrain      MSRP   Invoice  EngineSize  Cylinders  Horsepower  \
# ...

# %%
df = pd.read_csv('/Users/anu/Downloads/course/CARS_1.csv')
df
# Out:
#     name_of_car                    Model                             Type  \
# 0         Acura   NSX coupe 2dr manual S                           Sports
# 1         Acura  3.5 RL w/Navigation 4dr                            Sedan
# 2         Acura               3.5 RL 4dr                            Sedan
# 3         Acura                      MDX                              NaN
# 4         Acura                   TL 4dr                              NaN
# ..          ...                      ...                              ...
# 438         NaN                      NaN                              NaN
# 439         NaN                      NaN                              NaN
# 440         NaN                group by                1) data will split
# 441         NaN                      NaN  2) apply the function mean(mpg)
# 442         NaN                      NaN                       3) combine
#
#     Origin DriveTrain      MSRP   Invoice  EngineSize  Cylinders  Horsepower  \
# ...

# %%
df.head()
# Out:
#   name_of_car                    Model    Type Origin DriveTrain      MSRP  \
# 0       Acura   NSX coupe 2dr manual S  Sports   Asia       Rear  $89,765
# 1       Acura  3.5 RL w/Navigation 4dr   Sedan   Asia      Front  $46,100
# 2       Acura               3.5 RL 4dr   Sedan   Asia      Front  $43,755
# 3       Acura                      MDX     NaN   Asia        All  $36,945
# 4       Acura                   TL 4dr     NaN   Asia      Front  $33,195
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0  $79,978          3.2        6.0       290.0      17.0         24.0  3153.0
# 1  $41,100          3.5        6.0       225.0      18.0         24.0  3893.0
# 2  $39,014          3.5        6.0       225.0      18.0         24.0  3880.0
# 3       NaN         3.5        6.0       265.0      17.0         23.0  4451.0
# 4       NaN         3.2        6.0       270.0      20.0         28.0  3575.0
#
#    Wheelbase  Length  Unnamed: 15
# ...

# %%
df.tail()
# Out:
#     name_of_car      Model                             Type Origin DriveTrain  \
# 438         NaN        NaN                              NaN    NaN        NaN
# 439         NaN        NaN                              NaN    NaN        NaN
# 440         NaN  group by                1) data will split    NaN        NaN
# 441         NaN        NaN  2) apply the function mean(mpg)    NaN        NaN
# 442         NaN        NaN                       3) combine    NaN        NaN
#
#     MSRP Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 438  NaN     NaN         NaN        NaN         NaN       NaN          NaN
# 439  NaN     NaN         NaN        NaN         NaN       NaN          NaN
# 440  NaN     NaN         NaN        NaN         NaN       NaN          NaN
# 441  NaN     NaN         NaN        NaN         NaN       NaN          NaN
# 442  NaN     NaN         NaN        NaN         NaN       NaN          NaN
#
#      Weight  Wheelbase  Length  Unnamed: 15
# ...

# %%
df.shape
# Out:
# (443, 16)

# %%
df.size
# Out:
# 7088

# %%
len(df)
# Out:
# 443

# %%
df.columns
# Out:
# Index(['name_of_car', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP',
#        'Invoice', 'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City',
#        'MPG_Highway', 'Weight', 'Wheelbase', 'Length', 'Unnamed: 15'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name_of_car  428 non-null    object
#  1   Model        429 non-null    object
#  2   Type         409 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      406 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   343 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
#  15  Unnamed: 15  2 non-null      float64
# dtypes: float64(9), object(7)
# memory usage: 55.5+ KB

# %%
df.isnull().sum()
# Out:
# name_of_car     15
# Model           14
# Type            34
# Origin          15
# DriveTrain      15
# MSRP            15
# Invoice         37
# EngineSize      15
# Cylinders       17
# Horsepower     100
# MPG_City        15
# MPG_Highway     15
# Weight          15
# Wheelbase       15
# Length          15
# Unnamed: 15    441
# dtype: int64

# %%
df.isnull()
# Out:
#      name_of_car  Model   Type  Origin  DriveTrain   MSRP  Invoice  \
# 0          False  False  False   False       False  False    False
# 1          False  False  False   False       False  False    False
# 2          False  False  False   False       False  False    False
# 3          False  False   True   False       False  False     True
# 4          False  False   True   False       False  False     True
# ..           ...    ...    ...     ...         ...    ...      ...
# 438         True   True   True    True        True   True     True
# 439         True   True   True    True        True   True     True
# 440         True  False  False    True        True   True     True
# 441         True   True  False    True        True   True     True
# 442         True   True  False    True        True   True     True
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         False      False       False     False        False   False
# ...
